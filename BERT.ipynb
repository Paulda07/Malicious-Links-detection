# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
! ls
# Out:
# gdrive	sample_data

# %%
# %cd gdrive/My Drive/Malicious link detection
# Out:
# /content/gdrive/My Drive/ML_Project

# %%
! git clone https://github.com/ricardorei/lightning-text-classification
# Out:
# fatal: destination path 'lightning-text-classification' already exists and is not an empty directory.

# %%
! git pull
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# %cd lightning-text-classification
# Out:
# /content/gdrive/My Drive/ML_Project/lightning-text-classification

# %%
pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 10.5 MB 7.7 MB/s
# ...
#      |████████████████████████████████| 2.8 MB 38.8 MB/s
# ...
#      |████████████████████████████████| 6.9 MB 43.4 MB/s
# ...
#      |████████████████████████████████| 776.8 MB 17 kB/s
# ...
#      |████████████████████████████████| 884 kB 54.9 MB/s
# ...
#      |████████████████████████████████| 408 kB 70.1 MB/s
# ...
#      |████████████████████████████████| 90 kB 8.6 MB/s
# ...
#      |████████████████████████████████| 22.3 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 152 kB 67.7 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 59.6 MB/s
# ...
#      |████████████████████████████████| 880 kB 65.9 MB/s
# ...
#      |████████████████████████████████| 3.0 MB 47.6 MB/s
# ...
#      |████████████████████████████████| 829 kB 53.6 MB/s
# ...

# %%
# !python training.py
# Out:
# GPU available: True, used: True
# INFO:lightning:GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# INFO:lightning:TPU available: False, using: 0 TPU cores
# CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning:CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/utilities/distributed.py:37: UserWarning: Could not log computational graph since the `model.example_input_array` attribute is not set or `input_array` was not given
#   warnings.warn(*args, **kwargs)
#
#   | Name                | Type             | Params
# ---------------------------------------------------------
# 0 | bert                | BertModel        | 109 M
# 1 | classification_head | Sequential       | 2 M
# 2 | _loss               | CrossEntropyLoss | 0
# INFO:lightning:
#   | Name                | Type             | Params
# ---------------------------------------------------------
# 0 | bert                | BertModel        | 109 M
# ...

# %%
! python test.py --experiment 'experiments/version_17-11-2022--05-42-00' --test_data data/Webpages_Classification_test_data.csv
# Out:
# Loading model...
# Testing on data/Webpages_Classification_test_data.csv: 100% 2000/2000 [55:14<00:00,  1.66s/it]
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
